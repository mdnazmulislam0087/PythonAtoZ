# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Print is an inbuilt function. It is build by some one else. We are gonna use it.
#
# - shift+enter to Run the line

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("This is my first programm")
# Out:
# This is my first programm

# %% [markdown]
# Suppose you dont know what print function does; Then what you can do?
#
# - write the name of function and Press shift+Tab
# - shift +tab gives you dockstring

# %%
print
# Out:
# <function print>

# %% [markdown]
# Docstring:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
len
# Out:
# <function len(obj, /)>

# %%
1+2
# Out:
# 3

# %%
3/4
# Out:
# 0.75

# %%
5/6
# Out:
# 0.8333333333333334

# %%
5+7-90
# Out:
# -78

# %% [markdown]
# ![01.PNG](attachment:01.PNG)

# %% [markdown]
# Lets suppose 1+2 =3 ryt now if you want to reutilize 3 again then what you have to do????

# %%
1+2
# Out:
# 3

# %% [markdown]
# Variable is a entity that can hold the data(file, number e.t.c) in the main memory (CPU) to process and reutilze it.

# %%
a=4

# %%
a
# Out:
# 4

# %%
nazh=5456456

# %%
nazh
# Out:
# 5456456

# %% [markdown]
# in other language, you have to give input as intger, floating, complex etc but here it is not actually

# %%
type(nazh)
# Out:
# int

# %% [markdown]
# type  (shift+tab) to know the dockstring.

# %%
type(a)
# Out:
# int

# %%
b=1.23232

# %%
type(b)
# Out:
# float

# %%
c="My name is nazmul"

# %%
type(c)
# Out:
# str

# %%
d=5+6j  # J is giving imaginary number in Python

# %%
type(d)
# Out:
# complex

# %%
n=ghjghgh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-58180a54a25f> in <module>
# ----> 1 n=ghjghgh
#
# NameError: name 'ghjghgh' is not defined

# %% [markdown]
# - it gives you error; 20% coding 90% debugging. See the error to fix it ; try to debug it by yourself first.....
# - experience gives you debugging capability

# %%
n="fgfgfg"

# %%
n
# Out:
# 'fgfgfg'

# %% [markdown]
# - Now lets create a bulean variable; True and False where T / F is always in caps

# %%
p= True

# %%
p
# Out:
# True

# %%
type(p)
# Out:
# bool

# %%
a
# Out:
# 4

# %%
*a = 4
# Out:
#   File "<ipython-input-35-12092de0352e>", line 1
#     *a = 4
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
_a=45

# %%
_a
# Out:
# 45

# %%
a=34

# %%
a
# Out:
# 34

# %%
a=43
a=44

# %%
a
# Out:
# 44

# %%
a=5454
b="dfd"
c=6+9j
d=True
e=5.5

# %%
a
# Out:
# 5454

# %%
a1=4545

# %%
a+a1
# Out:
# 9999

# %%
a,b,c,d,e=234, "ffg", 5+7j, False, 5.6  # Single line variable creation

# %%
e
# Out:
# 5.6

# %%
a
# Out:
# 234

# %%
c
# Out:
# (5+7j)

# %%
a,b,c,d,e=234, "ffg", 5+7j, False  # Single line variable creation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-9ce4c455bbbe> in <module>
# ----> 1 a,b,c,d,e=234, "ffg", 5+7j, False  # Single line variable creation
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
c
# Out:
# (5+7j)

# %%
type(c)
# Out:
# complex

# %% [markdown]
# Lets suppose i want to see what are the inbuilt things(function we can get from C.
#
# - write the variable c and press Tab button
# - You will see what are the available function

# %%
c.
# Out:
#   File "<ipython-input-59-cf463a5954f9>", line 1
#     c.
#       ^
# SyntaxError: invalid syntax

# %%
c.imag
# Out:
# 7.0

# %%
c.real
# Out:
# 5.0

# %%
c.conjugate
# Out:
# <function complex.conjugate>

# %% [markdown]
# #### hence Shif tab and Variable(Tab)--- Most powerful

# %%
b.

# %%
a="Naaa"

# %%
b=8

# %%
a+b  # this is concatamation operation when string and int added
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-03c1aed0258d> in <module>
# ----> 1 a+b  # this is concatamation operation when string and int added
#
# TypeError: can only concatenate str (not "int") to str

# %%
a+"b"
# Out:
# 'Naaab'

# %%
a+"8"
# Out:
# 'Naaa8'

# %%
# or else we can do type casting
a+str(b) #type casting
# Out:
# 'Naaa8'

# %% [markdown]
#  hence string to int concatanation is not possible, if you want to do you have to do type casting

# %%
True+True
# Out:
# 2

# %%
True-False
# Out:
# 1

# %%
1+True
# Out:
# 2

# %% [markdown]
# # user input

# %%
input()
# Out:
# dfdfdf
# 'dfdfdf'

# %%
# to use for later stage create a variable
a=input()
# Out:
# Nazh

# %%
a
# Out:
# 'Nazh'

# %%
# input always gives string see the docstring by pressing shift tab

# %%
a=input()
# Out:
# 5

# %%
type(a)
# Out:
# str

# %%
b=5

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-ca730b97bf8a> in <module>
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # because a is string and  is int so concatation possible; to perform addition we need to type cast

# %%
int(a) +b
# Out:
# 10
